# %%
import pandas as pd
import numpy as np
import emoji
import string
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import unicodedata
import nltk
import re

portuguese_stopwords = nltk.corpus.stopwords.words('portuguese')

# transformando e abrindo o arquivo em formato csv
df = pd.read_excel('novo_df_classificar_sentimento_classificado.xlsx')

#
def preprocess_text(text, 
                    remove_stop = True, 
                    stem_words = False, 
                    remove_mentions_hashtags = True):
    """
    eg:
    input: preprocess_text("@water #dream hi hello where are you going be there tomorrow happening happen happens",  
    stem_words = True) 
    output: ['tomorrow', 'happen', 'go', 'hello']
    """

    # Remove emojis
    emoji_pattern = re.compile("[" "\U0001F1E0-\U0001F6FF" "]+", flags=re.UNICODE)
    text = emoji_pattern.sub(r"", text)
    text = "".join([x for x in text if x not in emoji.UNICODE_EMOJI])
    
    # Corrige o bud que elimina parte das palavras com acentos
    text = ''.join(ch for ch in unicodedata.normalize('NFKD', text) 
    if not unicodedata.combining(ch))

    if remove_mentions_hashtags:
        text = re.sub(r"@(\w+)", " ", text)
        text = re.sub(r"#(\w+)", " ", text)

    text = re.sub(r"[^\x00-\x7F]+", " ", text)
    regex = re.compile('[' + re.escape(string.punctuation) + '0-9\\r\\t\\n]')
    nopunct = regex.sub(" ", text.lower())
    words = (''.join(nopunct)).split()
    
    

    if(remove_stop):
        words = [w for w in words if w not in portuguese_stopwords]
        words = [w for w in words if len(w) > 2]  

    if(stem_words):
        stemmer = PorterStemmer()
        words = [stemmer.stem(w) for w in words]

    return list(words)

# %%
# carrega o dataset apenas com as colunas desejadas
df = df[['KEY','COMMENT_ID', 'COMMENT_TEXT','RATING_VALUE']]

df = df.dropna().reset_index().drop(columns=['index'])

# cria a coluna com textos vetorizados
rows, cols = df.shape

df['token'] = [preprocess_text(df["COMMENT_TEXT"][row]) for row in range(rows)]

lst_col = 'token'

df2 = pd.DataFrame({col:np.repeat(df[col].values, df[lst_col].str.len())
    for col in df.columns.difference([lst_col])}).assign(**{lst_col:np.concatenate(df[lst_col].values)})[df.columns.tolist()]

df2.head(20)
# Out:
#                                                   KEY COMMENT_ID  \
# 0   aHR0cHM6Ly93d3cuZXh0cmEuY29tLmJyL3NtYXJ0cGhvbm...    9021444
# 1   aHR0cHM6Ly93d3cuZXh0cmEuY29tLmJyL3NtYXJ0cGhvbm...    9021444
# 2   aHR0cHM6Ly93d3cuZXh0cmEuY29tLmJyL3NtYXJ0cGhvbm...    9021444
# 3   aHR0cHM6Ly93d3cuZXh0cmEuY29tLmJyL3NtYXJ0cGhvbm...    9021444
# 4   aHR0cHM6Ly93d3cuZXh0cmEuY29tLmJyL3NtYXJ0cGhvbm...    9021444
# 5   aHR0cHM6Ly93d3cuZXh0cmEuY29tLmJyL3NtYXJ0cGhvbm...    9021444
# 6   aHR0cHM6Ly93d3cuZXh0cmEuY29tLmJyL3NtYXJ0cGhvbm...    9021444
# 7   aHR0cHM6Ly93d3cuZXh0cmEuY29tLmJyL3NtYXJ0cGhvbm...    9021444
# 8   aHR0cHM6Ly93d3cuZXh0cmEuY29tLmJyL3NtYXJ0cGhvbm...    9021444
# 9   aHR0cHM6Ly93d3cuZXh0cmEuY29tLmJyL3NtYXJ0cGhvbm...    9021444
# 10  aHR0cHM6Ly93d3cuZXh0cmEuY29tLmJyL3NtYXJ0cGhvbm...    9021444
# 11  aHR0cHM6Ly93d3cucG9udG9mcmlvLmNvbS5ici9hcHBsZS...    4072603
# 12  aHR0cHM6Ly93d3cucG9udG9mcmlvLmNvbS5ici9hcHBsZS...    4072603
# 13  aHR0cHM6Ly93d3cucG9udG9mcmlvLmNvbS5ici9hcHBsZS...    4072603
# 14  aHR0cHM6Ly93d3cucG9udG9mcmlvLmNvbS5ici9hcHBsZS...    4072603
# 15  aHR0cHM6Ly93d3cucG9udG9mcmlvLmNvbS5ici9hcHBsZS...    4072603
# 16  aHR0cHM6Ly93d3cucG9udG9mcmlvLmNvbS5ici9hcHBsZS...    4072603
# 17  aHR0cHM6Ly93d3cuY2FzYXNiYWhpYS5jb20uYnIvc21hcn...    8709810
# 18  aHR0cHM6Ly93d3cuY2FzYXNiYWhpYS5jb20uYnIvc21hcn...    8709810
# 19  aHR0cHM6Ly93d3cuYW1lcmljYW5hcy5jb20uYnIvcHJvZH...  218881821
#
#                                          COMMENT_TEXT  RATING_VALUE  \
# 0   Antes desse eu tinha um motog6play e confesso ...             3
# 1   Antes desse eu tinha um motog6play e confesso ...             3
# 2   Antes desse eu tinha um motog6play e confesso ...             3
# 3   Antes desse eu tinha um motog6play e confesso ...             3
# 4   Antes desse eu tinha um motog6play e confesso ...             3
# 5   Antes desse eu tinha um motog6play e confesso ...             3
# 6   Antes desse eu tinha um motog6play e confesso ...             3
# 7   Antes desse eu tinha um motog6play e confesso ...             3
# 8   Antes desse eu tinha um motog6play e confesso ...             3
# 9   Antes desse eu tinha um motog6play e confesso ...             3
# 10  Antes desse eu tinha um motog6play e confesso ...             3
# 11  Valeu o preço dele, ainda mais para mim que co...             5
# 12  Valeu o preço dele, ainda mais para mim que co...             5
# 13  Valeu o preço dele, ainda mais para mim que co...             5
# 14  Valeu o preço dele, ainda mais para mim que co...             5
# 15  Valeu o preço dele, ainda mais para mim que co...             5
# 16  Valeu o preço dele, ainda mais para mim que co...             5
# 17                           Gostei estou satisfeita              5
# 18                           Gostei estou satisfeita              5
# 19  Parabéns pela rapidez na entrega, produto de ó...             4
#
#          token
# 0        antes
# 1        desse
# 2        motog
# 3         play
# 4     confesso
# 5      prefiro
# 6          mil
# 7        vezes
# 8        nesse
# 9          bom
# 10    preferia
# 11       valeu
# 12       preco
# 13       ainda
# 14         mim
# 15     comprei
# 16    desconto
# 17      gostei
# 18  satisfeita
# 19    parabens

# %%
df2.to_excel('novo_df_base_intermediaria_bag_of_words.xlsx')

# %%
stopwordsNltk = nltk.corpus.stopwords.words('portuguese')

words = []
for i in df.COMMENT_TEXT:
    for p in i.lower().split():
        if p not in stopwordsNltk:
            words.append(p)
            
words = str(words)

wordcloud = WordCloud(width = 1000, height= 800, margin = 0).generate(words)
plt.figure(figsize=(20,11))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)

# %%
words = str(df2['token'])

wordcloud = WordCloud(width = 1000, height= 800, margin = 0).generate(words)
plt.figure(figsize=(20,11))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
